# %% [markdown]
# * enable 8 TPUs
# * ResNet50 backbone
# * mixup disabled
# * use only TP samples
# * cut 6sec around annotation.
# * Stratified 5-fold and ensemble (just summing up probabilities)

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
from pathlib import Path
import io
import matplotlib.pyplot as plt
import soundfile as sf
import librosa
from kaggle_datasets import KaggleDatasets
from tqdm import tqdm
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import seaborn as sns
from IPython.display import Audio

tf.__version__
# Out:
# '2.2.0'

# %%
cfg = {
    'parse_params': {
        'cut_time': 10,
    },
    'data_params': {
        'sample_time': 6, # assert 60 % sample_time == 0
        'spec_fmax': 24000.0,
        'spec_fmin': 40.0,
        'spec_mel': 224,
        'mel_power': 2,
        'img_shape': (224, 512)
    },
    'model_params': {
        'batchsize_per_tpu': 16,
        'iteration_per_epoch': 64,
        'epoch': 100,
        'arch': tf.keras.applications.ResNet50,
        'arch_preprocess': tf.keras.applications.resnet50.preprocess_input,
        'freeze_to': 0,  # Freeze to backbone.layers[:freeze_to]. If None, all layers in the backbone will be freezed.
        'loss': {
            'fn': tfa.losses.SigmoidFocalCrossEntropy,
            'params': {},
        },
        'optim': {
            'fn': tfa.optimizers.RectifiedAdam,
            'params': {'lr': 1e-3, 'total_steps': 15*64, 'warmup_proportion': 0.3, 'min_lr': 1e-6},
        },
        'mixup': True
    }
}

# %%
# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU')]

# %%
strategy = tf.distribute.experimental.TPUStrategy(tpu)
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_DS_PATH = KaggleDatasets().get_gcs_path()

TRAIN_TFREC = GCS_DS_PATH + "/tfrecords/train"
TEST_TFREC = GCS_DS_PATH + "/tfrecords/test"

# %%
CUT = cfg['parse_params']['cut_time']
SR = 48000     # all wave's sample rate may be 48k

TIME = cfg['data_params']['sample_time']

FMAX = cfg['data_params']['spec_fmax']
FMIN = cfg['data_params']['spec_fmin']
N_MEL = cfg['data_params']['spec_mel']

HEIGHT, WIDTH = cfg['data_params']['img_shape']

CLASS_N = 24

# %% [markdown]
# # Explore the tfrecords, Create dataset

# %%
raw_dataset = tf.data.TFRecordDataset([TRAIN_TFREC + '/00-148.tfrec'])
raw_dataset
# Out:
# <TFRecordDatasetV2 shapes: (), types: tf.string>

# %% [markdown]
# ## parse tfrecords

# %%
feature_description = {
    'recording_id': tf.io.FixedLenFeature([], tf.string, default_value=''),
    'audio_wav': tf.io.FixedLenFeature([], tf.string, default_value=''),
    'label_info': tf.io.FixedLenFeature([], tf.string, default_value=''),
}
parse_dtype = {
    'audio_wav': tf.float32,
    'recording_id': tf.string,
    'species_id': tf.int32,
    'songtype_id': tf.int32,
    't_min': tf.float32,
    'f_min': tf.float32,
    't_max': tf.float32,
    'f_max':tf.float32,
    'is_tp': tf.int32
}

@tf.function
def _parse_function(example_proto):
    sample = tf.io.parse_single_example(example_proto, feature_description)
    wav, _ = tf.audio.decode_wav(sample['audio_wav'], desired_channels=1) # mono
    label_info = tf.strings.split(sample['label_info'], sep='"')[1]
    labels = tf.strings.split(label_info, sep=';')
    
    @tf.function
    def _cut_audio(label):
        items = tf.strings.split(label, sep=',')
        spid = tf.squeeze(tf.strings.to_number(items[0], tf.int32))
        soid = tf.squeeze(tf.strings.to_number(items[1], tf.int32))
        tmin = tf.squeeze(tf.strings.to_number(items[2]))
        fmin = tf.squeeze(tf.strings.to_number(items[3]))
        tmax = tf.squeeze(tf.strings.to_number(items[4]))
        fmax = tf.squeeze(tf.strings.to_number(items[5]))
        tp = tf.squeeze(tf.strings.to_number(items[6], tf.int32))

        tmax_s = tmax * tf.cast(SR, tf.float32)
        tmin_s = tmin * tf.cast(SR, tf.float32)
        cut_s = tf.cast(CUT * SR, tf.float32)
        all_s = tf.cast(60 * SR, tf.float32)
        tsize_s = tmax_s - tmin_s
        cut_min = tf.cast(
            tf.maximum(0.0, 
                tf.minimum(tmin_s - (cut_s - tsize_s) / 2,
                           tf.minimum(tmax_s + (cut_s - tsize_s) / 2, all_s) - cut_s)
            ), tf.int32
        )
        cut_max = cut_min + CUT * SR
        
        _sample = {
            'audio_wav': tf.reshape(wav[cut_min:cut_max], [CUT*SR]),
            'recording_id': sample['recording_id'],
            'species_id': spid,
            'songtype_id': soid,
            't_min': tmin - tf.cast(cut_min, tf.float32)/tf.cast(SR, tf.float32),
            'f_min': fmin,
            't_max': tmax - tf.cast(cut_min, tf.float32)/tf.cast(SR, tf.float32),
            'f_max': fmax,
            'is_tp': tp
        }
        return _sample
    
    samples = tf.map_fn(_cut_audio, labels, dtype=parse_dtype)
    return samples

parsed_dataset = raw_dataset.map(_parse_function).unbatch()

# %%
@tf.function
def _cut_wav(x):
    # random cut in training
    cut_min = tf.random.uniform([], maxval=(CUT-TIME)*SR, dtype=tf.int32)
    cut_max = cut_min + TIME * SR
    cutwave = tf.reshape(x['audio_wav'][cut_min:cut_max], [TIME*SR])
    y = {}
    y.update(x)
    y['audio_wav'] = cutwave
    y['t_min'] = tf.maximum(0.0, x['t_min'] - tf.cast(cut_min, tf.float32) / SR)
    y['t_max'] = tf.maximum(0.0, x['t_max'] - tf.cast(cut_min, tf.float32) / SR)
    return y
    
@tf.function
def _cut_wav_val(x):
    # center crop in validation
    cut_min = (CUT-TIME)*SR // 2
    cut_max = cut_min + TIME * SR
    cutwave = tf.reshape(x['audio_wav'][cut_min:cut_max], [TIME*SR])
    y = {}
    y.update(x)
    y['audio_wav'] = cutwave
    y['t_min'] = tf.maximum(0.0, x['t_min'] - tf.cast(cut_min, tf.float32) / SR)
    y['t_max'] = tf.maximum(0.0, x['t_max'] - tf.cast(cut_min, tf.float32) / SR)
    return y

# %%
@tf.function
def _filtTP(x):
    return x['is_tp'] == 1

# %%
def show_wav(sample, ax):
    wav = sample["audio_wav"].numpy()
    rate = SR
    ax.plot(np.arange(len(wav)) / rate, wav)
    ax.set_title(
        sample["recording_id"].numpy().decode()
        + ("/%d" % sample["species_id"])
        + ("TP" if sample["is_tp"] else "FP"))

    return Audio((wav * 2**15).astype(np.int16), rate=rate)

fig, ax = plt.subplots(figsize=(15, 3))
show_wav(next(iter(parsed_dataset)), ax)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## create mel-spectrogram

# %%
@tf.function
def _wav_to_spec(x):
    mel_power = cfg['data_params']['mel_power']
    
    stfts = tf.signal.stft(x["audio_wav"], frame_length=2048, frame_step=512, fft_length=2048)
    spectrograms = tf.abs(stfts) ** mel_power

    # Warp the linear scale spectrograms into the mel-scale.
    num_spectrogram_bins = stfts.shape[-1]
    lower_edge_hertz, upper_edge_hertz, num_mel_bins = FMIN, FMAX, N_MEL
    
    linear_to_mel_weight_matrix = tf.signal.linear_to_mel_weight_matrix(
      num_mel_bins, num_spectrogram_bins, SR, lower_edge_hertz,
      upper_edge_hertz)
    mel_spectrograms = tf.tensordot(
      spectrograms, linear_to_mel_weight_matrix, 1)
    mel_spectrograms.set_shape(spectrograms.shape[:-1].concatenate(
      linear_to_mel_weight_matrix.shape[-1:]))

    # Compute a stabilized log to get log-magnitude mel-scale spectrograms.
    log_mel_spectrograms = tf.math.log(mel_spectrograms + 1e-6)

    y = {
        'audio_spec': tf.transpose(log_mel_spectrograms), # (num_mel_bins, frames)
    }
    y.update(x)
    return y

spec_dataset = parsed_dataset.filter(_filtTP).map(_cut_wav).map(_wav_to_spec)

# %%
plt.figure(figsize=(12,5))
for i, s in enumerate(spec_dataset.take(3)):
    plt.subplot(1,3,i+1)
    plt.imshow(s['audio_spec'])
plt.show()

# %%
import librosa.display
import matplotlib.patches as patches

def show_spectrogram(sample, ax, showlabel=False):
    S_dB = sample["audio_spec"].numpy()
    img = librosa.display.specshow(S_dB, x_axis='time',
                             y_axis='mel', sr=SR,
                             fmax=FMAX, fmin=FMIN, ax=ax, cmap='magma')
    ax.set(title=f'Mel-frequency spectrogram of {sample["recording_id"].numpy().decode()}')
    sid, fmin, fmax, tmin, tmax, istp = (
            sample["species_id"], sample["f_min"], sample["f_max"], sample["t_min"], sample["t_max"], sample["is_tp"])
    ec = '#00ff00' if istp == 1 else '#0000ff'
    ax.add_patch(
        patches.Rectangle(xy=(tmin, fmin), width=tmax-tmin, height=fmax-fmin, ec=ec, fill=False)
    )

    if showlabel:
        ax.text(tmin, fmax, 
        f"{sid.numpy().item()} {'tp' if istp == 1 else 'fp'}",
        horizontalalignment='left', verticalalignment='bottom', color=ec, fontsize=16)

# %%
fig, ax = plt.subplots(figsize=(15,3))
show_spectrogram(next(iter(spec_dataset)), ax, showlabel=True)

# %%
# in validation, annotations will come to the center
fig, ax = plt.subplots(figsize=(15,3))
show_spectrogram(next(iter(parsed_dataset.filter(_filtTP).map(_cut_wav_val).map(_wav_to_spec))), ax, showlabel=True)

# %%
for sample in spec_dataset.take(5):
    fig, ax = plt.subplots(figsize=(15,3))
    show_spectrogram(sample, ax, showlabel=True)

# %% [markdown]
# ## create labels

# %%
@tf.function
def _create_annot(x):
    targ = tf.one_hot(x["species_id"], CLASS_N, on_value=x["is_tp"], off_value=0)
    
    return {
        'input': x["audio_spec"],
        'target': tf.cast(targ, tf.float32)
    }

annot_dataset = spec_dataset.map(_create_annot)

# %% [markdown]
# ## proprocessing and data augmentation
#
# In training, I use
#
# * gaussian noise
# * random brightness
# * specaugment

# %%
@tf.function
def _preprocess_img(x, training=False):
    image = tf.expand_dims(x, axis=-1)
    image = tf.image.resize(image, [HEIGHT, WIDTH])
    image = tf.image.per_image_standardization(image)
    
    @tf.function
    def _specaugment(image):
        ERASE_TIME = 50
        ERASE_MEL = 16
        image = tf.expand_dims(image, axis=0)
        xoff = tf.random.uniform([2], minval=ERASE_TIME//2, maxval=WIDTH-ERASE_TIME//2, dtype=tf.int32)
        xsize = tf.random.uniform([2], minval=ERASE_TIME//2, maxval=ERASE_TIME, dtype=tf.int32)
        yoff = tf.random.uniform([2], minval=ERASE_MEL//2, maxval=HEIGHT-ERASE_MEL//2, dtype=tf.int32)
        ysize = tf.random.uniform([2], minval=ERASE_MEL//2, maxval=ERASE_MEL, dtype=tf.int32)
        image = tfa.image.cutout(image, [HEIGHT, xsize[0]], offset=[HEIGHT//2, xoff[0]])
        image = tfa.image.cutout(image, [HEIGHT, xsize[1]], offset=[HEIGHT//2, xoff[1]])
        image = tfa.image.cutout(image, [ysize[0], WIDTH], offset=[yoff[0], WIDTH//2])
        image = tfa.image.cutout(image, [ysize[1], WIDTH], offset=[yoff[1], WIDTH//2])
        image = tf.squeeze(image, axis=0)
        return image
    
    if training:
        # gaussian
        gau = tf.keras.layers.GaussianNoise(0.3)
        image = tf.cond(tf.random.uniform([]) < 0.5, lambda: gau(image, training=True), lambda: image)
        # brightness
        image = tf.image.random_brightness(image, 0.2)
        # specaugment
        image = tf.cond(tf.random.uniform([]) < 0.5, lambda: _specaugment(image), lambda: image)
        
    image = (image - tf.reduce_min(image)) / (tf.reduce_max(image) - tf.reduce_min(image)) * 255.0 # rescale to [0, 255]
    image = tf.image.grayscale_to_rgb(image)
    image = cfg['model_params']['arch_preprocess'](image)

    return image

@tf.function
def _preprocess(x):
    image = _preprocess_img(x['input'], True)
    return (image, x["target"])

@tf.function
def _preprocess_val(x):
    image = _preprocess_img(x['input'], False)
    return (image, x["target"])

@tf.function
def _preprocess_test(x):
    image = _preprocess_img(x['audio_spec'], False)
    return (image, x["recording_id"])

# %%
for inp, targ in annot_dataset.map(_preprocess).take(2):
    plt.imshow(inp.numpy()[:,:,0])
    t = targ.numpy()
    if t.sum() == 0:
        plt.title(f'FP')
    else:
        plt.title(f'{t.nonzero()[0]}')
    plt.colorbar()
    plt.show()

# %% [markdown]
# # Model

# %%
def create_model():
    with strategy.scope():
        backbone = cfg['model_params']['arch'](include_top=False, weights='imagenet')
        
        if cfg['model_params']['freeze_to'] is None:
            for layer in backbone.layers:
                layer.trainable = False
        else:
            for layer in backbone.layers[:cfg['model_params']['freeze_to']]:
                layer.trainable = False

        model = tf.keras.Sequential([
            backbone,
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.4),
            tf.keras.layers.Dense(1024, activation='relu', kernel_initializer=tf.keras.initializers.he_normal()),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.4),
            tf.keras.layers.Dense(CLASS_N, bias_initializer=tf.keras.initializers.Constant(-2.))])
    return model

model = create_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, None, None, 2048)  23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                24600
# =================================================================
# Total params: 25,722,776
# Trainable params: 25,663,512
# Non-trainable params: 59,264
# _________________________________________________________________

# %%
@tf.function
def _mixup(inp, targ):
    indice = tf.range(len(inp))
    indice = tf.random.shuffle(indice)
    sinp = tf.gather(inp, indice, axis=0)
    starg = tf.gather(targ, indice, axis=0)
    
    alpha = 0.2
    t = tf.compat.v1.distributions.Beta(alpha, alpha).sample([len(inp)])
    tx = tf.reshape(t, [-1, 1, 1, 1])
    ty = tf.reshape(t, [-1, 1])
    x = inp * tx + sinp * (1-tx)
    y = targ * ty + starg * (1-ty)
#     y = tf.minimum(targ + starg, 1.0) # for multi-label???
    return x, y

# %%
tfrecs = sorted(tf.io.gfile.glob(TRAIN_TFREC + '/*.tfrec'))
parsed_trainval = (tf.data.TFRecordDataset(tfrecs, num_parallel_reads=AUTOTUNE)
                    .map(_parse_function, num_parallel_calls=AUTOTUNE).unbatch()
                    .filter(_filtTP).enumerate())

# %% [markdown]
# # Stratified 5-Fold

# %%
indices = []
spid = []
recid = []

for i, sample in tqdm(parsed_trainval.prefetch(AUTOTUNE)):
    indices.append(i.numpy())
    spid.append(sample['species_id'].numpy())
    recid.append(sample['recording_id'].numpy().decode())
# Out:
# 1216it [00:38, 31.38it/s]

# %%
table = pd.DataFrame({'indices': indices, 'species_id': spid, 'recording_id': recid})
table
# Out:
#       indices  species_id recording_id
# 0           0          14    003bec244
# 1           1          12    2026bced7
# 2           2          21    422de4e4d
# 3           3           6    60a493ad4
# 4           4          13    8080b2283
# ...       ...         ...          ...
# 1211     1211           3    807efd6bb
# 1212     1212          20    a6610076b
# 1213     1213          23    c91cae4aa
# 1214     1214           3    c91cae4aa
# 1215     1215           1    e755e15ec
#
# [1216 rows x 3 columns]

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
splits = list(skf.split(table.index, table.species_id))

plt.hist([table.loc[splits[0][0], 'species_id'], table.loc[splits[0][1], 'species_id']], bins=CLASS_N,stacked=True)
plt.show()

# %%
def create_idx_filter(indice):
    @tf.function
    def _filt(i, x):
        return tf.reduce_any(indice == i)
    return _filt

@tf.function
def _remove_idx(i, x):
    return x

# %% [markdown]
# # Other setup

# %%
def create_train_dataset(batchsize, train_idx):
    global parsed_trainval
    parsed_train = (parsed_trainval
                    .filter(create_idx_filter(train_idx))
                    .map(_remove_idx))
    
    dataset = (parsed_train.cache()
        .shuffle(len(train_idx))
        .repeat()
        .map(_cut_wav, num_parallel_calls=AUTOTUNE)
        .map(_wav_to_spec, num_parallel_calls=AUTOTUNE)
        .map(_create_annot, num_parallel_calls=AUTOTUNE)
        .map(_preprocess, num_parallel_calls=AUTOTUNE)
        .batch(batchsize))

    if cfg['model_params']['mixup']:
        dataset = (dataset.map(_mixup, num_parallel_calls=AUTOTUNE)
                    .prefetch(AUTOTUNE))
    else:
        dataset = dataset.prefetch(AUTOTUNE)
    return dataset

def create_val_dataset(batchsize, val_idx):
    global parsed_trainval
    parsed_val = (parsed_trainval
                  .filter(create_idx_filter(val_idx))
                  .map(_remove_idx))

    vdataset = (parsed_val
        .map(_cut_wav_val, num_parallel_calls=AUTOTUNE)
        .map(_wav_to_spec, num_parallel_calls=AUTOTUNE)
        .map(_create_annot, num_parallel_calls=AUTOTUNE)
        .map(_preprocess_val, num_parallel_calls=AUTOTUNE)
        .batch(8*strategy.num_replicas_in_sync)
        .cache())
    return vdataset

# %% [markdown]
# # Metrics

# %%
# from https://www.kaggle.com/carlthome/l-lrap-metric-for-tf-keras
@tf.function
def _one_sample_positive_class_precisions(example):
    y_true, y_pred = example

    retrieved_classes = tf.argsort(y_pred, direction='DESCENDING')
    class_rankings = tf.argsort(retrieved_classes)
    retrieved_class_true = tf.gather(y_true, retrieved_classes)
    retrieved_cumulative_hits = tf.math.cumsum(tf.cast(retrieved_class_true, tf.float32))

    idx = tf.where(y_true)[:, 0]
    i = tf.boolean_mask(class_rankings, y_true)
    r = tf.gather(retrieved_cumulative_hits, i)
    c = 1 + tf.cast(i, tf.float32)
    precisions = r / c

    dense = tf.scatter_nd(idx[:, None], precisions, [y_pred.shape[0]])
    return dense

class LWLRAP(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name='lwlrap'):
        super().__init__(name=name)

        self._precisions = self.add_weight(
            name='per_class_cumulative_precision',
            shape=[num_classes],
            initializer='zeros',
        )

        self._counts = self.add_weight(
            name='per_class_cumulative_count',
            shape=[num_classes],
            initializer='zeros',
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        precisions = tf.map_fn(
            fn=_one_sample_positive_class_precisions,
            elems=(y_true, y_pred),
            dtype=(tf.float32),
        )

        increments = tf.cast(precisions > 0, tf.float32)
        total_increments = tf.reduce_sum(increments, axis=0)
        total_precisions = tf.reduce_sum(precisions, axis=0)

        self._precisions.assign_add(total_precisions)
        self._counts.assign_add(total_increments)        

    def result(self):
        per_class_lwlrap = self._precisions / tf.maximum(self._counts, 1.0)
        per_class_weight = self._counts / tf.reduce_sum(self._counts)
        overall_lwlrap = tf.reduce_sum(per_class_lwlrap * per_class_weight)
        return overall_lwlrap

    def reset_states(self):
        self._precisions.assign(self._precisions * 0)
        self._counts.assign(self._counts * 0)

# %% [markdown]
# # Testset and Inference function

# %%
def _parse_function_test(example_proto):
    sample = tf.io.parse_single_example(example_proto, feature_description)
    wav, _ = tf.audio.decode_wav(sample['audio_wav'], desired_channels=1) # mono
    
    @tf.function
    def _cut_audio(i):
        _sample = {
            'audio_wav': tf.reshape(wav[i*SR*TIME:(i+1)*SR*TIME], [SR*TIME]),
            'recording_id': sample['recording_id']
        }
        return _sample

    return tf.map_fn(_cut_audio, tf.range(60//TIME), dtype={
        'audio_wav': tf.float32,
        'recording_id': tf.string
    })

def inference(model):
    tdataset = (tf.data.TFRecordDataset(tf.io.gfile.glob(TEST_TFREC + '/*.tfrec'), num_parallel_reads=AUTOTUNE)
        .map(_parse_function_test, num_parallel_calls=AUTOTUNE).unbatch()
        .map(_wav_to_spec, num_parallel_calls=AUTOTUNE)
        .map(_preprocess_test, num_parallel_calls=AUTOTUNE)
        .batch(128*(60//TIME)).prefetch(AUTOTUNE))
    
    rec_ids = []
    probs = []
    for inp, rec_id in tqdm(tdataset):
        with strategy.scope():
            pred = model.predict_on_batch(tf.reshape(inp, [-1, HEIGHT, WIDTH, 3]))
            prob = tf.sigmoid(pred)
            prob = tf.reduce_max(tf.reshape(prob, [-1, 60//TIME, CLASS_N]), axis=1)

        rec_id_stack = tf.reshape(rec_id, [-1, 60//TIME])
        for rec in rec_id.numpy():
            assert len(np.unique(rec)) == 1
        rec_ids.append(rec_id_stack.numpy()[:,0])
        probs.append(prob.numpy())
        
    crec_ids = np.concatenate(rec_ids)
    cprobs = np.concatenate(probs)
    
    sub = pd.DataFrame({
        'recording_id': list(map(lambda x: x.decode(), crec_ids.tolist())),
        **{f's{i}': cprobs[:,i] for i in range(CLASS_N)}
    })
    sub = sub.sort_values('recording_id')
    return sub

# %% [markdown]
# # Now start training!

# %%
def plot_history(history, name):
    plt.figure(figsize=(8,3))
    plt.subplot(1,2,1)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.title("loss")
    # plt.yscale('log')

    plt.subplot(1,2,2)
    plt.plot(history.history["lwlrap"])
    plt.plot(history.history["val_lwlrap"])
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.title("metric")

    plt.savefig(name)

# %%
def train_and_inference(splits, split_id):
    batchsize = cfg['model_params']['batchsize_per_tpu'] * strategy.num_replicas_in_sync
    print("batchsize", batchsize)
    loss_fn = cfg['model_params']['loss']['fn'](from_logits=True, **cfg['model_params']['loss']['params'])

    idx_train_tf = tf.constant(splits[split_id][0])
    idx_val_tf = tf.constant(splits[split_id][1])

    dataset = create_train_dataset(batchsize, idx_train_tf)
    vdataset = create_val_dataset(batchsize, idx_val_tf)
    
    optimizer = cfg['model_params']['optim']['fn'](**cfg['model_params']['optim']['params'])
    model = create_model()
    with strategy.scope():
        model.compile(optimizer=optimizer, loss=loss_fn, metrics=[LWLRAP(CLASS_N)])
        
    history = model.fit(dataset,
                        steps_per_epoch=cfg['model_params']['iteration_per_epoch'],
                        epochs=cfg['model_params']['epoch'],
                        validation_data=vdataset,
                        callbacks=[
                            tf.keras.callbacks.ReduceLROnPlateau(
                                'val_lwlrap', patience=10
                            ),
                            tf.keras.callbacks.ModelCheckpoint(
                                filepath='model_best_%d.h5' % split_id,
                                save_weights_only=True,
                                monitor='val_lwlrap',
                                mode='max',
                                save_best_only=True),
                        ])
    plot_history(history, 'history_%d.png' % split_id)
    
    ### inference ###
    model.load_weights('model_best_%d.h5' % split_id)
    return inference(model), history

# %%
# train and inference
# sub, _ = train_and_inference(splits, 0)

# N-fold ensemble
sub = sum(
    map(
        lambda i: train_and_inference(splits, i)[0].set_index('recording_id'),
        range(len(splits))
    )
).reset_index()
# Out:
# batchsize 128
# Epoch 1/100
# 64/64 [==============================] - 49s 772ms/step - lwlrap: 0.1549 - loss: 2.2424 - val_lwlrap: 0.1833 - val_loss: 0.6449 - lr: 0.0010
# Epoch 2/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.1797 - loss: 1.7020 - val_lwlrap: 0.1865 - val_loss: 0.6080 - lr: 0.0010
# Epoch 3/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.2230 - loss: 1.1187 - val_lwlrap: 0.2467 - val_loss: 0.4653 - lr: 0.0010
# Epoch 4/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.2587 - loss: 0.7503 - val_lwlrap: 0.3509 - val_loss: 0.3953 - lr: 0.0010
# Epoch 5/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.3402 - loss: 0.5973 - val_lwlrap: 0.4943 - val_loss: 0.3153 - lr: 0.0010
# Epoch 6/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.4395 - loss: 0.5076 - val_lwlrap: 0.6084 - val_loss: 0.2660 - lr: 0.0010
# Epoch 7/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.5461 - loss: 0.4463 - val_lwlrap: 0.6690 - val_loss: 0.3276 - lr: 0.0010
# Epoch 8/100
# 64/64 [==============================] - 19s 297ms/step - lwlrap: 0.6283 - loss: 0.3867 - val_lwlrap: 0.7339 - val_loss: 0.2231 - lr: 0.0010
# Epoch 9/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.6914 - loss: 0.3541 - val_lwlrap: 0.7372 - val_loss: 0.2839 - lr: 0.0010
# Epoch 10/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.7239 - loss: 0.3227 - val_lwlrap: 0.7437 - val_loss: 0.2136 - lr: 0.0010
# Epoch 11/100
# 64/64 [==============================] - 19s 294ms/step - lwlrap: 0.7401 - loss: 0.3204 - val_lwlrap: 0.7939 - val_loss: 0.1891 - lr: 0.0010
# Epoch 12/100
# 64/64 [==============================] - 19s 294ms/step - lwlrap: 0.7767 - loss: 0.2994 - val_lwlrap: 0.8314 - val_loss: 0.1646 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.7530 - loss: 0.2907 - val_lwlrap: 0.8307 - val_loss: 0.3651 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - 19s 296ms/step - lwlrap: 0.7910 - loss: 0.2834 - val_lwlrap: 0.8376 - val_loss: 0.3535 - lr: 1.0000e-04
# Epoch 15/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.7948 - loss: 0.2841 - val_lwlrap: 0.8434 - val_loss: 0.2778 - lr: 1.0000e-04
# Epoch 16/100
# 64/64 [==============================] - 17s 265ms/step - lwlrap: 0.7632 - loss: 0.2818 - val_lwlrap: 0.8426 - val_loss: 0.2784 - lr: 1.0000e-04
# Epoch 17/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.7698 - loss: 0.2926 - val_lwlrap: 0.8429 - val_loss: 0.2719 - lr: 1.0000e-04
# Epoch 18/100
# 64/64 [==============================] - 17s 263ms/step - lwlrap: 0.7855 - loss: 0.2799 - val_lwlrap: 0.8413 - val_loss: 0.3260 - lr: 1.0000e-04
# Epoch 19/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8063 - loss: 0.2857 - val_lwlrap: 0.8425 - val_loss: 0.3437 - lr: 1.0000e-04
# Epoch 20/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.7998 - loss: 0.2843 - val_lwlrap: 0.8444 - val_loss: 0.3615 - lr: 1.0000e-04
# Epoch 21/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.7993 - loss: 0.2823 - val_lwlrap: 0.8432 - val_loss: 0.3610 - lr: 1.0000e-04
# Epoch 22/100
# 64/64 [==============================] - 20s 318ms/step - lwlrap: 0.7863 - loss: 0.2818 - val_lwlrap: 0.8447 - val_loss: 0.3216 - lr: 1.0000e-05
# Epoch 23/100
# 64/64 [==============================] - 17s 265ms/step - lwlrap: 0.7871 - loss: 0.2827 - val_lwlrap: 0.8442 - val_loss: 0.3206 - lr: 1.0000e-05
# Epoch 24/100
# 64/64 [==============================] - 19s 293ms/step - lwlrap: 0.7923 - loss: 0.2830 - val_lwlrap: 0.8469 - val_loss: 0.3614 - lr: 1.0000e-05
# Epoch 25/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8030 - loss: 0.2825 - val_lwlrap: 0.8403 - val_loss: 0.3599 - lr: 1.0000e-05
# Epoch 26/100
# 64/64 [==============================] - 16s 256ms/step - lwlrap: 0.8036 - loss: 0.2786 - val_lwlrap: 0.8447 - val_loss: 0.3723 - lr: 1.0000e-05
# Epoch 27/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.7829 - loss: 0.2857 - val_lwlrap: 0.8482 - val_loss: 0.3317 - lr: 1.0000e-05
# Epoch 28/100
# 64/64 [==============================] - 17s 263ms/step - lwlrap: 0.7732 - loss: 0.2804 - val_lwlrap: 0.8455 - val_loss: 0.3494 - lr: 1.0000e-05
# Epoch 29/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.8066 - loss: 0.2857 - val_lwlrap: 0.8453 - val_loss: 0.3398 - lr: 1.0000e-05
# Epoch 30/100
# 64/64 [==============================] - 19s 299ms/step - lwlrap: 0.7785 - loss: 0.2801 - val_lwlrap: 0.8495 - val_loss: 0.3665 - lr: 1.0000e-05
# Epoch 31/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.7777 - loss: 0.2775 - val_lwlrap: 0.8440 - val_loss: 0.3058 - lr: 1.0000e-05
# Epoch 32/100
# 64/64 [==============================] - 17s 262ms/step - lwlrap: 0.7991 - loss: 0.2830 - val_lwlrap: 0.8454 - val_loss: 0.3668 - lr: 1.0000e-06
# Epoch 33/100
# 64/64 [==============================] - 17s 266ms/step - lwlrap: 0.8030 - loss: 0.2769 - val_lwlrap: 0.8451 - val_loss: 0.4039 - lr: 1.0000e-06
# Epoch 34/100
# 64/64 [==============================] - 16s 257ms/step - lwlrap: 0.7865 - loss: 0.2792 - val_lwlrap: 0.8467 - val_loss: 0.5039 - lr: 1.0000e-06
# Epoch 35/100
# 64/64 [==============================] - 17s 271ms/step - lwlrap: 0.8322 - loss: 0.2786 - val_lwlrap: 0.8418 - val_loss: 0.4851 - lr: 1.0000e-06
# Epoch 36/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.7799 - loss: 0.2786 - val_lwlrap: 0.8449 - val_loss: 0.4135 - lr: 1.0000e-06
# Epoch 37/100
# 64/64 [==============================] - 19s 296ms/step - lwlrap: 0.7936 - loss: 0.2770 - val_lwlrap: 0.8509 - val_loss: 0.3759 - lr: 1.0000e-06
# Epoch 38/100
# 64/64 [==============================] - 17s 266ms/step - lwlrap: 0.7711 - loss: 0.2833 - val_lwlrap: 0.8461 - val_loss: 0.3709 - lr: 1.0000e-06
# Epoch 39/100
# 64/64 [==============================] - 17s 259ms/step - lwlrap: 0.7996 - loss: 0.2832 - val_lwlrap: 0.8456 - val_loss: 0.4386 - lr: 1.0000e-06
# Epoch 40/100
# 64/64 [==============================] - 17s 258ms/step - lwlrap: 0.7751 - loss: 0.2765 - val_lwlrap: 0.8487 - val_loss: 0.5152 - lr: 1.0000e-06
# Epoch 41/100
# 64/64 [==============================] - 17s 259ms/step - lwlrap: 0.7923 - loss: 0.2803 - val_lwlrap: 0.8504 - val_loss: 0.4826 - lr: 1.0000e-06
# Epoch 42/100
# 64/64 [==============================] - 17s 267ms/step - lwlrap: 0.8077 - loss: 0.2790 - val_lwlrap: 0.8502 - val_loss: 0.4732 - lr: 1.0000e-07
# Epoch 43/100
# 64/64 [==============================] - 19s 300ms/step - lwlrap: 0.7998 - loss: 0.2742 - val_lwlrap: 0.8522 - val_loss: 0.5618 - lr: 1.0000e-07
# Epoch 44/100
# 64/64 [==============================] - 16s 258ms/step - lwlrap: 0.7750 - loss: 0.2772 - val_lwlrap: 0.8518 - val_loss: 0.6552 - lr: 1.0000e-07
# Epoch 45/100
# 64/64 [==============================] - 19s 298ms/step - lwlrap: 0.7850 - loss: 0.2738 - val_lwlrap: 0.8550 - val_loss: 0.6088 - lr: 1.0000e-07
# Epoch 46/100
# 64/64 [==============================] - 17s 261ms/step - lwlrap: 0.7800 - loss: 0.2749 - val_lwlrap: 0.8491 - val_loss: 0.6661 - lr: 1.0000e-07
# Epoch 47/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8091 - loss: 0.2771 - val_lwlrap: 0.8525 - val_loss: 0.7114 - lr: 1.0000e-07
# Epoch 48/100
# 64/64 [==============================] - 17s 263ms/step - lwlrap: 0.7909 - loss: 0.2771 - val_lwlrap: 0.8522 - val_loss: 0.7083 - lr: 1.0000e-07
# Epoch 49/100
# 64/64 [==============================] - 17s 259ms/step - lwlrap: 0.7948 - loss: 0.2730 - val_lwlrap: 0.8501 - val_loss: 0.7305 - lr: 1.0000e-07
# Epoch 50/100
# 64/64 [==============================] - 17s 271ms/step - lwlrap: 0.7806 - loss: 0.2760 - val_lwlrap: 0.8533 - val_loss: 0.7709 - lr: 1.0000e-07
# Epoch 51/100
# 64/64 [==============================] - 17s 267ms/step - lwlrap: 0.8021 - loss: 0.2661 - val_lwlrap: 0.8472 - val_loss: 0.6789 - lr: 1.0000e-07
# Epoch 52/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8030 - loss: 0.2689 - val_lwlrap: 0.8465 - val_loss: 0.7180 - lr: 1.0000e-08
# Epoch 53/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8049 - loss: 0.2710 - val_lwlrap: 0.8493 - val_loss: 0.6718 - lr: 1.0000e-08
# Epoch 54/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.7902 - loss: 0.2736 - val_lwlrap: 0.8483 - val_loss: 0.6593 - lr: 1.0000e-08
# Epoch 55/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8101 - loss: 0.2676 - val_lwlrap: 0.8452 - val_loss: 0.6541 - lr: 1.0000e-08
# Epoch 56/100
# 64/64 [==============================] - 17s 270ms/step - lwlrap: 0.8187 - loss: 0.2671 - val_lwlrap: 0.8489 - val_loss: 0.8260 - lr: 1.0000e-08
# Epoch 57/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.7989 - loss: 0.2662 - val_lwlrap: 0.8501 - val_loss: 0.8643 - lr: 1.0000e-08
# Epoch 58/100
# 64/64 [==============================] - 18s 278ms/step - lwlrap: 0.7993 - loss: 0.2650 - val_lwlrap: 0.8524 - val_loss: 0.8383 - lr: 1.0000e-08
# Epoch 59/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.8240 - loss: 0.2690 - val_lwlrap: 0.8511 - val_loss: 0.8055 - lr: 1.0000e-08
# Epoch 60/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8295 - loss: 0.2667 - val_lwlrap: 0.8538 - val_loss: 0.8429 - lr: 1.0000e-08
# Epoch 61/100
# 64/64 [==============================] - 19s 298ms/step - lwlrap: 0.8145 - loss: 0.2683 - val_lwlrap: 0.8498 - val_loss: 1.0626 - lr: 1.0000e-08
# Epoch 62/100
# 64/64 [==============================] - 17s 265ms/step - lwlrap: 0.8228 - loss: 0.2663 - val_lwlrap: 0.8491 - val_loss: 1.1318 - lr: 1.0000e-09
# Epoch 63/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8038 - loss: 0.2634 - val_lwlrap: 0.8508 - val_loss: 1.1309 - lr: 1.0000e-09
# Epoch 64/100
# 64/64 [==============================] - 17s 272ms/step - lwlrap: 0.8128 - loss: 0.2610 - val_lwlrap: 0.8508 - val_loss: 1.0328 - lr: 1.0000e-09
# Epoch 65/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.7977 - loss: 0.2637 - val_lwlrap: 0.8508 - val_loss: 1.0495 - lr: 1.0000e-09
# Epoch 66/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.7829 - loss: 0.2618 - val_lwlrap: 0.8486 - val_loss: 1.0347 - lr: 1.0000e-09
# Epoch 67/100
# 64/64 [==============================] - 18s 274ms/step - lwlrap: 0.8153 - loss: 0.2652 - val_lwlrap: 0.8539 - val_loss: 1.1049 - lr: 1.0000e-09
# Epoch 68/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8340 - loss: 0.2584 - val_lwlrap: 0.8493 - val_loss: 1.1202 - lr: 1.0000e-09
# Epoch 69/100
# 64/64 [==============================] - 18s 275ms/step - lwlrap: 0.8236 - loss: 0.2585 - val_lwlrap: 0.8491 - val_loss: 1.1309 - lr: 1.0000e-09
# Epoch 70/100
# 64/64 [==============================] - 20s 308ms/step - lwlrap: 0.8373 - loss: 0.2632 - val_lwlrap: 0.8563 - val_loss: 1.1912 - lr: 1.0000e-09
# Epoch 71/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.8077 - loss: 0.2640 - val_lwlrap: 0.8521 - val_loss: 1.1696 - lr: 1.0000e-09
# Epoch 72/100
# 64/64 [==============================] - 17s 259ms/step - lwlrap: 0.8130 - loss: 0.2629 - val_lwlrap: 0.8498 - val_loss: 1.0982 - lr: 1.0000e-10
# Epoch 73/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8069 - loss: 0.2590 - val_lwlrap: 0.8506 - val_loss: 1.1019 - lr: 1.0000e-10
# Epoch 74/100
# 64/64 [==============================] - 18s 275ms/step - lwlrap: 0.8218 - loss: 0.2553 - val_lwlrap: 0.8517 - val_loss: 0.9971 - lr: 1.0000e-10
# Epoch 75/100
# 64/64 [==============================] - 18s 274ms/step - lwlrap: 0.8329 - loss: 0.2593 - val_lwlrap: 0.8540 - val_loss: 1.1678 - lr: 1.0000e-10
# Epoch 76/100
# 64/64 [==============================] - 18s 277ms/step - lwlrap: 0.8173 - loss: 0.2603 - val_lwlrap: 0.8547 - val_loss: 1.2921 - lr: 1.0000e-10
# Epoch 77/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8101 - loss: 0.2590 - val_lwlrap: 0.8549 - val_loss: 1.1325 - lr: 1.0000e-10
# Epoch 78/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8183 - loss: 0.2594 - val_lwlrap: 0.8536 - val_loss: 1.2526 - lr: 1.0000e-10
# Epoch 79/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8212 - loss: 0.2557 - val_lwlrap: 0.8535 - val_loss: 1.2881 - lr: 1.0000e-10
# Epoch 80/100
# 64/64 [==============================] - 17s 262ms/step - lwlrap: 0.8160 - loss: 0.2569 - val_lwlrap: 0.8532 - val_loss: 1.1805 - lr: 1.0000e-10
# Epoch 81/100
# 64/64 [==============================] - 18s 278ms/step - lwlrap: 0.8346 - loss: 0.2545 - val_lwlrap: 0.8560 - val_loss: 1.1843 - lr: 1.0000e-10
# Epoch 82/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8238 - loss: 0.2594 - val_lwlrap: 0.8557 - val_loss: 1.2189 - lr: 1.0000e-11
# Epoch 83/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.8234 - loss: 0.2561 - val_lwlrap: 0.8558 - val_loss: 1.3430 - lr: 1.0000e-11
# Epoch 84/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8168 - loss: 0.2589 - val_lwlrap: 0.8509 - val_loss: 1.2280 - lr: 1.0000e-11
# Epoch 85/100
# 64/64 [==============================] - 18s 278ms/step - lwlrap: 0.8292 - loss: 0.2565 - val_lwlrap: 0.8525 - val_loss: 1.3175 - lr: 1.0000e-11
# Epoch 86/100
# 64/64 [==============================] - 17s 272ms/step - lwlrap: 0.8140 - loss: 0.2573 - val_lwlrap: 0.8524 - val_loss: 1.2863 - lr: 1.0000e-11
# Epoch 87/100
# 64/64 [==============================] - 18s 277ms/step - lwlrap: 0.8354 - loss: 0.2547 - val_lwlrap: 0.8558 - val_loss: 1.2850 - lr: 1.0000e-11
# Epoch 88/100
# 64/64 [==============================] - 18s 275ms/step - lwlrap: 0.8371 - loss: 0.2503 - val_lwlrap: 0.8494 - val_loss: 1.2786 - lr: 1.0000e-11
# Epoch 89/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8223 - loss: 0.2502 - val_lwlrap: 0.8475 - val_loss: 1.2443 - lr: 1.0000e-11
# Epoch 90/100
# 64/64 [==============================] - 18s 277ms/step - lwlrap: 0.8249 - loss: 0.2495 - val_lwlrap: 0.8509 - val_loss: 1.1881 - lr: 1.0000e-11
# Epoch 91/100
# 64/64 [==============================] - 19s 304ms/step - lwlrap: 0.8304 - loss: 0.2515 - val_lwlrap: 0.8583 - val_loss: 1.1098 - lr: 1.0000e-11
# Epoch 92/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.8418 - loss: 0.2530 - val_lwlrap: 0.8550 - val_loss: 1.1954 - lr: 1.0000e-12
# Epoch 93/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.8119 - loss: 0.2503 - val_lwlrap: 0.8546 - val_loss: 1.2558 - lr: 1.0000e-12
# Epoch 94/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.8368 - loss: 0.2547 - val_lwlrap: 0.8546 - val_loss: 1.0874 - lr: 1.0000e-12
# Epoch 95/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8169 - loss: 0.2493 - val_lwlrap: 0.8491 - val_loss: 1.0562 - lr: 1.0000e-12
# Epoch 96/100
# 64/64 [==============================] - 20s 310ms/step - lwlrap: 0.8523 - loss: 0.2471 - val_lwlrap: 0.8583 - val_loss: 1.1060 - lr: 1.0000e-12
# Epoch 97/100
# 64/64 [==============================] - 17s 261ms/step - lwlrap: 0.8367 - loss: 0.2502 - val_lwlrap: 0.8514 - val_loss: 1.0853 - lr: 1.0000e-12
# Epoch 98/100
# 64/64 [==============================] - 19s 302ms/step - lwlrap: 0.8419 - loss: 0.2517 - val_lwlrap: 0.8598 - val_loss: 0.8853 - lr: 1.0000e-12
# Epoch 99/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8366 - loss: 0.2477 - val_lwlrap: 0.8549 - val_loss: 1.1774 - lr: 1.0000e-12
# Epoch 100/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8256 - loss: 0.2529 - val_lwlrap: 0.8551 - val_loss: 1.1477 - lr: 1.0000e-12
# 16it [01:09,  4.32s/it]
# batchsize 128
# Epoch 1/100
# 64/64 [==============================] - 50s 788ms/step - lwlrap: 0.1743 - loss: 2.1698 - val_lwlrap: 0.1827 - val_loss: 0.9559 - lr: 0.0010
# Epoch 2/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.1994 - loss: 1.7348 - val_lwlrap: 0.1973 - val_loss: 1.1276 - lr: 0.0010
# Epoch 3/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.2171 - loss: 1.2811 - val_lwlrap: 0.2060 - val_loss: 1.3354 - lr: 0.0010
# Epoch 4/100
# 64/64 [==============================] - 19s 296ms/step - lwlrap: 0.2781 - loss: 0.8496 - val_lwlrap: 0.3230 - val_loss: 10.8231 - lr: 0.0010
# Epoch 5/100
# 64/64 [==============================] - 19s 294ms/step - lwlrap: 0.3671 - loss: 0.6143 - val_lwlrap: 0.4386 - val_loss: 2.4774 - lr: 0.0010
# Epoch 6/100
# 64/64 [==============================] - 19s 298ms/step - lwlrap: 0.4669 - loss: 0.4910 - val_lwlrap: 0.6202 - val_loss: 1.4552 - lr: 0.0010
# Epoch 7/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.5865 - loss: 0.4198 - val_lwlrap: 0.6777 - val_loss: 0.2466 - lr: 0.0010
# Epoch 8/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.6796 - loss: 0.3562 - val_lwlrap: 0.7663 - val_loss: 0.2407 - lr: 0.0010
# Epoch 9/100
# 64/64 [==============================] - 19s 298ms/step - lwlrap: 0.7147 - loss: 0.3230 - val_lwlrap: 0.8019 - val_loss: 0.1823 - lr: 0.0010
# Epoch 10/100
# 64/64 [==============================] - 17s 262ms/step - lwlrap: 0.7735 - loss: 0.2854 - val_lwlrap: 0.7981 - val_loss: 0.1790 - lr: 0.0010
# Epoch 11/100
# 64/64 [==============================] - 19s 298ms/step - lwlrap: 0.8215 - loss: 0.2653 - val_lwlrap: 0.8092 - val_loss: 0.1720 - lr: 0.0010
# Epoch 12/100
# 64/64 [==============================] - 20s 314ms/step - lwlrap: 0.8397 - loss: 0.2553 - val_lwlrap: 0.8284 - val_loss: 0.1733 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - 20s 305ms/step - lwlrap: 0.8271 - loss: 0.2539 - val_lwlrap: 0.8346 - val_loss: 0.1771 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8326 - loss: 0.2527 - val_lwlrap: 0.8310 - val_loss: 0.1825 - lr: 1.0000e-04
# Epoch 15/100
# 64/64 [==============================] - 17s 265ms/step - lwlrap: 0.8272 - loss: 0.2462 - val_lwlrap: 0.8331 - val_loss: 0.1847 - lr: 1.0000e-04
# Epoch 16/100
# 64/64 [==============================] - 20s 307ms/step - lwlrap: 0.8192 - loss: 0.2448 - val_lwlrap: 0.8346 - val_loss: 0.1856 - lr: 1.0000e-04
# Epoch 17/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.8376 - loss: 0.2521 - val_lwlrap: 0.8361 - val_loss: 0.1853 - lr: 1.0000e-04
# Epoch 18/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.8402 - loss: 0.2480 - val_lwlrap: 0.8338 - val_loss: 0.1854 - lr: 1.0000e-04
# Epoch 19/100
# 64/64 [==============================] - 17s 271ms/step - lwlrap: 0.8325 - loss: 0.2488 - val_lwlrap: 0.8301 - val_loss: 0.1861 - lr: 1.0000e-04
# Epoch 20/100
# 64/64 [==============================] - 17s 258ms/step - lwlrap: 0.8384 - loss: 0.2475 - val_lwlrap: 0.8354 - val_loss: 0.1862 - lr: 1.0000e-04
# Epoch 21/100
# 64/64 [==============================] - 17s 266ms/step - lwlrap: 0.8292 - loss: 0.2455 - val_lwlrap: 0.8351 - val_loss: 0.1863 - lr: 1.0000e-04
# Epoch 22/100
# 64/64 [==============================] - 16s 255ms/step - lwlrap: 0.8262 - loss: 0.2495 - val_lwlrap: 0.8342 - val_loss: 0.1859 - lr: 1.0000e-05
# Epoch 23/100
# 64/64 [==============================] - 19s 300ms/step - lwlrap: 0.8482 - loss: 0.2428 - val_lwlrap: 0.8375 - val_loss: 0.1857 - lr: 1.0000e-05
# Epoch 24/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8264 - loss: 0.2434 - val_lwlrap: 0.8352 - val_loss: 0.1858 - lr: 1.0000e-05
# Epoch 25/100
# 64/64 [==============================] - 17s 262ms/step - lwlrap: 0.8387 - loss: 0.2450 - val_lwlrap: 0.8327 - val_loss: 0.1867 - lr: 1.0000e-05
# Epoch 26/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.8252 - loss: 0.2454 - val_lwlrap: 0.8346 - val_loss: 0.1867 - lr: 1.0000e-05
# Epoch 27/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8095 - loss: 0.2497 - val_lwlrap: 0.8330 - val_loss: 0.1869 - lr: 1.0000e-05
# Epoch 28/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8409 - loss: 0.2448 - val_lwlrap: 0.8321 - val_loss: 0.1876 - lr: 1.0000e-05
# Epoch 29/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8272 - loss: 0.2452 - val_lwlrap: 0.8295 - val_loss: 0.1870 - lr: 1.0000e-05
# Epoch 30/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.8324 - loss: 0.2464 - val_lwlrap: 0.8325 - val_loss: 0.1876 - lr: 1.0000e-05
# Epoch 31/100
# 64/64 [==============================] - 19s 304ms/step - lwlrap: 0.8456 - loss: 0.2408 - val_lwlrap: 0.8329 - val_loss: 0.1862 - lr: 1.0000e-05
# Epoch 32/100
# 64/64 [==============================] - 17s 267ms/step - lwlrap: 0.8556 - loss: 0.2463 - val_lwlrap: 0.8343 - val_loss: 0.1883 - lr: 1.0000e-06
# Epoch 33/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8382 - loss: 0.2454 - val_lwlrap: 0.8306 - val_loss: 0.1878 - lr: 1.0000e-06
# Epoch 34/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8398 - loss: 0.2414 - val_lwlrap: 0.8312 - val_loss: 0.1867 - lr: 1.0000e-06
# Epoch 35/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8221 - loss: 0.2462 - val_lwlrap: 0.8339 - val_loss: 0.1868 - lr: 1.0000e-06
# Epoch 36/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8379 - loss: 0.2456 - val_lwlrap: 0.8323 - val_loss: 0.1857 - lr: 1.0000e-06
# Epoch 37/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8534 - loss: 0.2432 - val_lwlrap: 0.8329 - val_loss: 0.1856 - lr: 1.0000e-06
# Epoch 38/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8497 - loss: 0.2467 - val_lwlrap: 0.8329 - val_loss: 0.1859 - lr: 1.0000e-06
# Epoch 39/100
# 64/64 [==============================] - 19s 292ms/step - lwlrap: 0.8347 - loss: 0.2381 - val_lwlrap: 0.8326 - val_loss: 0.1860 - lr: 1.0000e-06
# Epoch 40/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8371 - loss: 0.2383 - val_lwlrap: 0.8333 - val_loss: 0.1862 - lr: 1.0000e-06
# Epoch 41/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8531 - loss: 0.2433 - val_lwlrap: 0.8324 - val_loss: 0.1860 - lr: 1.0000e-06
# Epoch 42/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8398 - loss: 0.2449 - val_lwlrap: 0.8342 - val_loss: 0.1866 - lr: 1.0000e-07
# Epoch 43/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8219 - loss: 0.2440 - val_lwlrap: 0.8320 - val_loss: 0.1860 - lr: 1.0000e-07
# Epoch 44/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8344 - loss: 0.2426 - val_lwlrap: 0.8354 - val_loss: 0.1862 - lr: 1.0000e-07
# Epoch 45/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8443 - loss: 0.2385 - val_lwlrap: 0.8349 - val_loss: 0.1862 - lr: 1.0000e-07
# Epoch 46/100
# 64/64 [==============================] - 19s 294ms/step - lwlrap: 0.8360 - loss: 0.2409 - val_lwlrap: 0.8328 - val_loss: 0.1865 - lr: 1.0000e-07
# Epoch 47/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8389 - loss: 0.2413 - val_lwlrap: 0.8327 - val_loss: 0.1873 - lr: 1.0000e-07
# Epoch 48/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8417 - loss: 0.2388 - val_lwlrap: 0.8332 - val_loss: 0.1865 - lr: 1.0000e-07
# Epoch 49/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8382 - loss: 0.2403 - val_lwlrap: 0.8284 - val_loss: 0.1874 - lr: 1.0000e-07
# Epoch 50/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8547 - loss: 0.2390 - val_lwlrap: 0.8334 - val_loss: 0.1864 - lr: 1.0000e-07
# Epoch 51/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.8479 - loss: 0.2401 - val_lwlrap: 0.8283 - val_loss: 0.1866 - lr: 1.0000e-07
# Epoch 52/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.8409 - loss: 0.2399 - val_lwlrap: 0.8309 - val_loss: 0.1861 - lr: 1.0000e-08
# Epoch 53/100
# 64/64 [==============================] - 18s 278ms/step - lwlrap: 0.8208 - loss: 0.2406 - val_lwlrap: 0.8303 - val_loss: 0.1865 - lr: 1.0000e-08
# Epoch 54/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8427 - loss: 0.2387 - val_lwlrap: 0.8309 - val_loss: 0.1859 - lr: 1.0000e-08
# Epoch 55/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.8357 - loss: 0.2408 - val_lwlrap: 0.8314 - val_loss: 0.1868 - lr: 1.0000e-08
# Epoch 56/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8451 - loss: 0.2409 - val_lwlrap: 0.8296 - val_loss: 0.1875 - lr: 1.0000e-08
# Epoch 57/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8677 - loss: 0.2392 - val_lwlrap: 0.8331 - val_loss: 0.1876 - lr: 1.0000e-08
# Epoch 58/100
# 64/64 [==============================] - 19s 292ms/step - lwlrap: 0.8627 - loss: 0.2375 - val_lwlrap: 0.8310 - val_loss: 0.1869 - lr: 1.0000e-08
# Epoch 59/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8545 - loss: 0.2346 - val_lwlrap: 0.8343 - val_loss: 0.1875 - lr: 1.0000e-08
# Epoch 60/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8609 - loss: 0.2345 - val_lwlrap: 0.8297 - val_loss: 0.1884 - lr: 1.0000e-08
# Epoch 61/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8399 - loss: 0.2362 - val_lwlrap: 0.8304 - val_loss: 0.1883 - lr: 1.0000e-08
# Epoch 62/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8393 - loss: 0.2368 - val_lwlrap: 0.8316 - val_loss: 0.1884 - lr: 1.0000e-09
# Epoch 63/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8387 - loss: 0.2357 - val_lwlrap: 0.8315 - val_loss: 0.1876 - lr: 1.0000e-09
# Epoch 64/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8475 - loss: 0.2377 - val_lwlrap: 0.8304 - val_loss: 0.1879 - lr: 1.0000e-09
# Epoch 65/100
# 64/64 [==============================] - 19s 298ms/step - lwlrap: 0.8546 - loss: 0.2345 - val_lwlrap: 0.8304 - val_loss: 0.1880 - lr: 1.0000e-09
# Epoch 66/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8373 - loss: 0.2377 - val_lwlrap: 0.8347 - val_loss: 0.1885 - lr: 1.0000e-09
# Epoch 67/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8589 - loss: 0.2326 - val_lwlrap: 0.8299 - val_loss: 0.1875 - lr: 1.0000e-09
# Epoch 68/100
# 64/64 [==============================] - 19s 293ms/step - lwlrap: 0.8184 - loss: 0.2341 - val_lwlrap: 0.8290 - val_loss: 0.1886 - lr: 1.0000e-09
# Epoch 69/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8476 - loss: 0.2352 - val_lwlrap: 0.8331 - val_loss: 0.1884 - lr: 1.0000e-09
# Epoch 70/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8418 - loss: 0.2333 - val_lwlrap: 0.8353 - val_loss: 0.1875 - lr: 1.0000e-09
# Epoch 71/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8586 - loss: 0.2301 - val_lwlrap: 0.8353 - val_loss: 0.1886 - lr: 1.0000e-09
# Epoch 72/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8569 - loss: 0.2321 - val_lwlrap: 0.8331 - val_loss: 0.1883 - lr: 1.0000e-10
# Epoch 73/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8628 - loss: 0.2318 - val_lwlrap: 0.8320 - val_loss: 0.1889 - lr: 1.0000e-10
# Epoch 74/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8507 - loss: 0.2278 - val_lwlrap: 0.8312 - val_loss: 0.1892 - lr: 1.0000e-10
# Epoch 75/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8515 - loss: 0.2284 - val_lwlrap: 0.8317 - val_loss: 0.1901 - lr: 1.0000e-10
# Epoch 76/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8563 - loss: 0.2296 - val_lwlrap: 0.8338 - val_loss: 0.1909 - lr: 1.0000e-10
# Epoch 77/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8571 - loss: 0.2304 - val_lwlrap: 0.8331 - val_loss: 0.1890 - lr: 1.0000e-10
# Epoch 78/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8738 - loss: 0.2294 - val_lwlrap: 0.8331 - val_loss: 0.1884 - lr: 1.0000e-10
# Epoch 79/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8618 - loss: 0.2284 - val_lwlrap: 0.8369 - val_loss: 0.1880 - lr: 1.0000e-10
# Epoch 80/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8744 - loss: 0.2286 - val_lwlrap: 0.8323 - val_loss: 0.1886 - lr: 1.0000e-10
# Epoch 81/100
# 64/64 [==============================] - 21s 330ms/step - lwlrap: 0.8511 - loss: 0.2281 - val_lwlrap: 0.8384 - val_loss: 0.1889 - lr: 1.0000e-10
# Epoch 82/100
# 64/64 [==============================] - 16s 257ms/step - lwlrap: 0.8641 - loss: 0.2333 - val_lwlrap: 0.8367 - val_loss: 0.1889 - lr: 1.0000e-11
# Epoch 83/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.8630 - loss: 0.2273 - val_lwlrap: 0.8383 - val_loss: 0.1893 - lr: 1.0000e-11
# Epoch 84/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8745 - loss: 0.2242 - val_lwlrap: 0.8353 - val_loss: 0.1895 - lr: 1.0000e-11
# Epoch 85/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8586 - loss: 0.2271 - val_lwlrap: 0.8363 - val_loss: 0.1895 - lr: 1.0000e-11
# Epoch 86/100
# 64/64 [==============================] - 21s 321ms/step - lwlrap: 0.8343 - loss: 0.2299 - val_lwlrap: 0.8393 - val_loss: 0.1892 - lr: 1.0000e-11
# Epoch 87/100
# 64/64 [==============================] - 17s 265ms/step - lwlrap: 0.8750 - loss: 0.2260 - val_lwlrap: 0.8364 - val_loss: 0.1901 - lr: 1.0000e-11
# Epoch 88/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.8440 - loss: 0.2219 - val_lwlrap: 0.8351 - val_loss: 0.1906 - lr: 1.0000e-11
# Epoch 89/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8612 - loss: 0.2237 - val_lwlrap: 0.8380 - val_loss: 0.1897 - lr: 1.0000e-11
# Epoch 90/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8833 - loss: 0.2204 - val_lwlrap: 0.8358 - val_loss: 0.1894 - lr: 1.0000e-11
# Epoch 91/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8591 - loss: 0.2285 - val_lwlrap: 0.8343 - val_loss: 0.1894 - lr: 1.0000e-11
# Epoch 92/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8808 - loss: 0.2253 - val_lwlrap: 0.8368 - val_loss: 0.1900 - lr: 1.0000e-12
# Epoch 93/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8578 - loss: 0.2278 - val_lwlrap: 0.8372 - val_loss: 0.1903 - lr: 1.0000e-12
# Epoch 94/100
# 64/64 [==============================] - 21s 330ms/step - lwlrap: 0.8654 - loss: 0.2222 - val_lwlrap: 0.8378 - val_loss: 0.1897 - lr: 1.0000e-12
# Epoch 95/100
# 64/64 [==============================] - 17s 259ms/step - lwlrap: 0.8647 - loss: 0.2237 - val_lwlrap: 0.8372 - val_loss: 0.1904 - lr: 1.0000e-12
# Epoch 96/100
# 64/64 [==============================] - 17s 270ms/step - lwlrap: 0.8835 - loss: 0.2232 - val_lwlrap: 0.8385 - val_loss: 0.1902 - lr: 1.0000e-12
# Epoch 97/100
# 64/64 [==============================] - 21s 324ms/step - lwlrap: 0.8661 - loss: 0.2256 - val_lwlrap: 0.8397 - val_loss: 0.1908 - lr: 1.0000e-12
# Epoch 98/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.8825 - loss: 0.2219 - val_lwlrap: 0.8391 - val_loss: 0.1904 - lr: 1.0000e-12
# Epoch 99/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.8683 - loss: 0.2199 - val_lwlrap: 0.8345 - val_loss: 0.1906 - lr: 1.0000e-12
# Epoch 100/100
# 64/64 [==============================] - 20s 320ms/step - lwlrap: 0.8690 - loss: 0.2194 - val_lwlrap: 0.8403 - val_loss: 0.1908 - lr: 1.0000e-12
# 16it [01:03,  3.98s/it]
# batchsize 128
# Epoch 1/100
# 64/64 [==============================] - 50s 779ms/step - lwlrap: 0.1726 - loss: 2.2104 - val_lwlrap: 0.1615 - val_loss: 0.6406 - lr: 0.0010
# Epoch 2/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.2004 - loss: 1.7285 - val_lwlrap: 0.1744 - val_loss: 0.6674 - lr: 0.0010
# Epoch 3/100
# 64/64 [==============================] - 19s 297ms/step - lwlrap: 0.2388 - loss: 1.1895 - val_lwlrap: 0.2471 - val_loss: 0.6300 - lr: 0.0010
# Epoch 4/100
# 64/64 [==============================] - 19s 304ms/step - lwlrap: 0.2672 - loss: 0.7915 - val_lwlrap: 0.3113 - val_loss: 0.4661 - lr: 0.0010
# Epoch 5/100
# 64/64 [==============================] - 20s 305ms/step - lwlrap: 0.3796 - loss: 0.5815 - val_lwlrap: 0.4516 - val_loss: 0.3426 - lr: 0.0010
# Epoch 6/100
# 64/64 [==============================] - 19s 300ms/step - lwlrap: 0.5083 - loss: 0.4983 - val_lwlrap: 0.6436 - val_loss: 0.2598 - lr: 0.0010
# Epoch 7/100
# 64/64 [==============================] - 19s 301ms/step - lwlrap: 0.5666 - loss: 0.4393 - val_lwlrap: 0.6703 - val_loss: 0.2369 - lr: 0.0010
# Epoch 8/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.6400 - loss: 0.4011 - val_lwlrap: 0.7725 - val_loss: 0.2016 - lr: 0.0010
# Epoch 9/100
# 64/64 [==============================] - 20s 306ms/step - lwlrap: 0.7066 - loss: 0.3601 - val_lwlrap: 0.8129 - val_loss: 0.1676 - lr: 0.0010
# Epoch 10/100
# 64/64 [==============================] - 19s 301ms/step - lwlrap: 0.7359 - loss: 0.3402 - val_lwlrap: 0.8542 - val_loss: 0.1563 - lr: 0.0010
# Epoch 11/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.7319 - loss: 0.3302 - val_lwlrap: 0.8330 - val_loss: 0.1631 - lr: 0.0010
# Epoch 12/100
# 64/64 [==============================] - 17s 270ms/step - lwlrap: 0.7714 - loss: 0.3162 - val_lwlrap: 0.8424 - val_loss: 0.1631 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.7434 - loss: 0.3110 - val_lwlrap: 0.8523 - val_loss: 0.1634 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - 17s 262ms/step - lwlrap: 0.7377 - loss: 0.3047 - val_lwlrap: 0.8456 - val_loss: 0.1624 - lr: 1.0000e-04
# Epoch 15/100
# 64/64 [==============================] - 17s 269ms/step - lwlrap: 0.7367 - loss: 0.3101 - val_lwlrap: 0.8445 - val_loss: 0.1635 - lr: 1.0000e-04
# Epoch 16/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.7703 - loss: 0.3126 - val_lwlrap: 0.8479 - val_loss: 0.1626 - lr: 1.0000e-04
# Epoch 17/100
# 64/64 [==============================] - 18s 274ms/step - lwlrap: 0.7690 - loss: 0.3048 - val_lwlrap: 0.8482 - val_loss: 0.1617 - lr: 1.0000e-04
# Epoch 18/100
# 64/64 [==============================] - 17s 260ms/step - lwlrap: 0.7661 - loss: 0.3029 - val_lwlrap: 0.8520 - val_loss: 0.1619 - lr: 1.0000e-04
# Epoch 19/100
# 64/64 [==============================] - 21s 321ms/step - lwlrap: 0.7788 - loss: 0.3045 - val_lwlrap: 0.8564 - val_loss: 0.1625 - lr: 1.0000e-04
# Epoch 20/100
# 64/64 [==============================] - 18s 274ms/step - lwlrap: 0.7735 - loss: 0.3025 - val_lwlrap: 0.8564 - val_loss: 0.1606 - lr: 1.0000e-04
# Epoch 21/100
# 64/64 [==============================] - 19s 300ms/step - lwlrap: 0.7533 - loss: 0.3065 - val_lwlrap: 0.8521 - val_loss: 0.1613 - lr: 1.0000e-04
# Epoch 22/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.7599 - loss: 0.3010 - val_lwlrap: 0.8560 - val_loss: 0.1604 - lr: 1.0000e-05
# Epoch 23/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.7854 - loss: 0.3007 - val_lwlrap: 0.8538 - val_loss: 0.1612 - lr: 1.0000e-05
# Epoch 24/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.7741 - loss: 0.3002 - val_lwlrap: 0.8538 - val_loss: 0.1612 - lr: 1.0000e-05
# Epoch 25/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.7676 - loss: 0.3102 - val_lwlrap: 0.8530 - val_loss: 0.1622 - lr: 1.0000e-05
# Epoch 26/100
# 64/64 [==============================] - 19s 294ms/step - lwlrap: 0.7955 - loss: 0.3014 - val_lwlrap: 0.8502 - val_loss: 0.1631 - lr: 1.0000e-05
# Epoch 27/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.7640 - loss: 0.3055 - val_lwlrap: 0.8519 - val_loss: 0.1629 - lr: 1.0000e-05
# Epoch 28/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.7816 - loss: 0.2981 - val_lwlrap: 0.8520 - val_loss: 0.1617 - lr: 1.0000e-05
# Epoch 29/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.7855 - loss: 0.3023 - val_lwlrap: 0.8517 - val_loss: 0.1620 - lr: 1.0000e-05
# Epoch 30/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.7857 - loss: 0.3058 - val_lwlrap: 0.8537 - val_loss: 0.1620 - lr: 1.0000e-05
# Epoch 31/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.7526 - loss: 0.3031 - val_lwlrap: 0.8533 - val_loss: 0.1609 - lr: 1.0000e-05
# Epoch 32/100
# 64/64 [==============================] - 20s 320ms/step - lwlrap: 0.7767 - loss: 0.3001 - val_lwlrap: 0.8571 - val_loss: 0.1624 - lr: 1.0000e-06
# Epoch 33/100
# 64/64 [==============================] - 20s 308ms/step - lwlrap: 0.7751 - loss: 0.3066 - val_lwlrap: 0.8571 - val_loss: 0.1618 - lr: 1.0000e-06
# Epoch 34/100
# 64/64 [==============================] - 17s 269ms/step - lwlrap: 0.7772 - loss: 0.3060 - val_lwlrap: 0.8548 - val_loss: 0.1621 - lr: 1.0000e-06
# Epoch 35/100
# 64/64 [==============================] - 17s 265ms/step - lwlrap: 0.7699 - loss: 0.2983 - val_lwlrap: 0.8544 - val_loss: 0.1618 - lr: 1.0000e-06
# Epoch 36/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.7764 - loss: 0.2983 - val_lwlrap: 0.8542 - val_loss: 0.1624 - lr: 1.0000e-06
# Epoch 37/100
# 64/64 [==============================] - 18s 278ms/step - lwlrap: 0.7732 - loss: 0.2991 - val_lwlrap: 0.8550 - val_loss: 0.1615 - lr: 1.0000e-06
# Epoch 38/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.7984 - loss: 0.2991 - val_lwlrap: 0.8538 - val_loss: 0.1617 - lr: 1.0000e-06
# Epoch 39/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.7912 - loss: 0.3050 - val_lwlrap: 0.8549 - val_loss: 0.1610 - lr: 1.0000e-06
# Epoch 40/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.7810 - loss: 0.3021 - val_lwlrap: 0.8565 - val_loss: 0.1622 - lr: 1.0000e-06
# Epoch 41/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.7592 - loss: 0.2971 - val_lwlrap: 0.8541 - val_loss: 0.1618 - lr: 1.0000e-06
# Epoch 42/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.7843 - loss: 0.3015 - val_lwlrap: 0.8530 - val_loss: 0.1603 - lr: 1.0000e-07
# Epoch 43/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.7836 - loss: 0.2960 - val_lwlrap: 0.8545 - val_loss: 0.1611 - lr: 1.0000e-07
# Epoch 44/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.7666 - loss: 0.3004 - val_lwlrap: 0.8552 - val_loss: 0.1622 - lr: 1.0000e-07
# Epoch 45/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8001 - loss: 0.2978 - val_lwlrap: 0.8563 - val_loss: 0.1617 - lr: 1.0000e-07
# Epoch 46/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.7914 - loss: 0.2967 - val_lwlrap: 0.8533 - val_loss: 0.1630 - lr: 1.0000e-07
# Epoch 47/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.7745 - loss: 0.2980 - val_lwlrap: 0.8560 - val_loss: 0.1618 - lr: 1.0000e-07
# Epoch 48/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8052 - loss: 0.2971 - val_lwlrap: 0.8561 - val_loss: 0.1622 - lr: 1.0000e-07
# Epoch 49/100
# 64/64 [==============================] - 21s 329ms/step - lwlrap: 0.7266 - loss: 0.2980 - val_lwlrap: 0.8605 - val_loss: 0.1618 - lr: 1.0000e-07
# Epoch 50/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.7683 - loss: 0.2939 - val_lwlrap: 0.8582 - val_loss: 0.1617 - lr: 1.0000e-07
# Epoch 51/100
# 64/64 [==============================] - 17s 266ms/step - lwlrap: 0.7698 - loss: 0.2920 - val_lwlrap: 0.8569 - val_loss: 0.1612 - lr: 1.0000e-07
# Epoch 52/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8157 - loss: 0.2943 - val_lwlrap: 0.8569 - val_loss: 0.1627 - lr: 1.0000e-08
# Epoch 53/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.7961 - loss: 0.2981 - val_lwlrap: 0.8550 - val_loss: 0.1596 - lr: 1.0000e-08
# Epoch 54/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8081 - loss: 0.2955 - val_lwlrap: 0.8573 - val_loss: 0.1610 - lr: 1.0000e-08
# Epoch 55/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.7829 - loss: 0.2924 - val_lwlrap: 0.8545 - val_loss: 0.1609 - lr: 1.0000e-08
# Epoch 56/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8035 - loss: 0.2904 - val_lwlrap: 0.8561 - val_loss: 0.1616 - lr: 1.0000e-08
# Epoch 57/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.7886 - loss: 0.2903 - val_lwlrap: 0.8546 - val_loss: 0.1622 - lr: 1.0000e-08
# Epoch 58/100
# 64/64 [==============================] - 19s 294ms/step - lwlrap: 0.8055 - loss: 0.2948 - val_lwlrap: 0.8566 - val_loss: 0.1612 - lr: 1.0000e-08
# Epoch 59/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.7859 - loss: 0.2879 - val_lwlrap: 0.8581 - val_loss: 0.1606 - lr: 1.0000e-08
# Epoch 60/100
# 64/64 [==============================] - 18s 277ms/step - lwlrap: 0.8019 - loss: 0.2883 - val_lwlrap: 0.8587 - val_loss: 0.1612 - lr: 1.0000e-08
# Epoch 61/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.7974 - loss: 0.2948 - val_lwlrap: 0.8594 - val_loss: 0.1627 - lr: 1.0000e-08
# Epoch 62/100
# 64/64 [==============================] - 19s 293ms/step - lwlrap: 0.8044 - loss: 0.2903 - val_lwlrap: 0.8554 - val_loss: 0.1616 - lr: 1.0000e-09
# Epoch 63/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.7978 - loss: 0.2910 - val_lwlrap: 0.8558 - val_loss: 0.1598 - lr: 1.0000e-09
# Epoch 64/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.7924 - loss: 0.2876 - val_lwlrap: 0.8602 - val_loss: 0.1622 - lr: 1.0000e-09
# Epoch 65/100
# 64/64 [==============================] - 21s 330ms/step - lwlrap: 0.7905 - loss: 0.2888 - val_lwlrap: 0.8617 - val_loss: 0.1625 - lr: 1.0000e-09
# Epoch 66/100
# 64/64 [==============================] - 17s 267ms/step - lwlrap: 0.8048 - loss: 0.2854 - val_lwlrap: 0.8583 - val_loss: 0.1621 - lr: 1.0000e-09
# Epoch 67/100
# 64/64 [==============================] - 17s 262ms/step - lwlrap: 0.7619 - loss: 0.2896 - val_lwlrap: 0.8586 - val_loss: 0.1624 - lr: 1.0000e-09
# Epoch 68/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.7814 - loss: 0.2876 - val_lwlrap: 0.8603 - val_loss: 0.1617 - lr: 1.0000e-09
# Epoch 69/100
# 64/64 [==============================] - 21s 329ms/step - lwlrap: 0.8180 - loss: 0.2886 - val_lwlrap: 0.8625 - val_loss: 0.1616 - lr: 1.0000e-09
# Epoch 70/100
# 64/64 [==============================] - 17s 263ms/step - lwlrap: 0.8075 - loss: 0.2833 - val_lwlrap: 0.8589 - val_loss: 0.1613 - lr: 1.0000e-09
# Epoch 71/100
# 64/64 [==============================] - 20s 310ms/step - lwlrap: 0.8114 - loss: 0.2925 - val_lwlrap: 0.8637 - val_loss: 0.1617 - lr: 1.0000e-09
# Epoch 72/100
# 64/64 [==============================] - 17s 272ms/step - lwlrap: 0.8070 - loss: 0.2855 - val_lwlrap: 0.8588 - val_loss: 0.1614 - lr: 1.0000e-10
# Epoch 73/100
# 64/64 [==============================] - 17s 265ms/step - lwlrap: 0.7969 - loss: 0.2903 - val_lwlrap: 0.8618 - val_loss: 0.1611 - lr: 1.0000e-10
# Epoch 74/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8089 - loss: 0.2817 - val_lwlrap: 0.8613 - val_loss: 0.1599 - lr: 1.0000e-10
# Epoch 75/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.7837 - loss: 0.2863 - val_lwlrap: 0.8616 - val_loss: 0.1609 - lr: 1.0000e-10
# Epoch 76/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.7838 - loss: 0.2941 - val_lwlrap: 0.8590 - val_loss: 0.1604 - lr: 1.0000e-10
# Epoch 77/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8171 - loss: 0.2840 - val_lwlrap: 0.8611 - val_loss: 0.1597 - lr: 1.0000e-10
# Epoch 78/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.8049 - loss: 0.2868 - val_lwlrap: 0.8622 - val_loss: 0.1595 - lr: 1.0000e-10
# Epoch 79/100
# 64/64 [==============================] - 21s 323ms/step - lwlrap: 0.8006 - loss: 0.2818 - val_lwlrap: 0.8651 - val_loss: 0.1595 - lr: 1.0000e-10
# Epoch 80/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.8098 - loss: 0.2902 - val_lwlrap: 0.8614 - val_loss: 0.1593 - lr: 1.0000e-10
# Epoch 81/100
# 64/64 [==============================] - 18s 274ms/step - lwlrap: 0.8124 - loss: 0.2816 - val_lwlrap: 0.8611 - val_loss: 0.1610 - lr: 1.0000e-10
# Epoch 82/100
# 64/64 [==============================] - 20s 317ms/step - lwlrap: 0.7784 - loss: 0.2905 - val_lwlrap: 0.8704 - val_loss: 0.1603 - lr: 1.0000e-11
# Epoch 83/100
# 64/64 [==============================] - 17s 266ms/step - lwlrap: 0.7933 - loss: 0.2815 - val_lwlrap: 0.8663 - val_loss: 0.1582 - lr: 1.0000e-11
# Epoch 84/100
# 64/64 [==============================] - 17s 272ms/step - lwlrap: 0.7988 - loss: 0.2883 - val_lwlrap: 0.8671 - val_loss: 0.1597 - lr: 1.0000e-11
# Epoch 85/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.7950 - loss: 0.2856 - val_lwlrap: 0.8619 - val_loss: 0.1615 - lr: 1.0000e-11
# Epoch 86/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8179 - loss: 0.2848 - val_lwlrap: 0.8604 - val_loss: 0.1618 - lr: 1.0000e-11
# Epoch 87/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.7999 - loss: 0.2835 - val_lwlrap: 0.8668 - val_loss: 0.1605 - lr: 1.0000e-11
# Epoch 88/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8058 - loss: 0.2777 - val_lwlrap: 0.8693 - val_loss: 0.1601 - lr: 1.0000e-11
# Epoch 89/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.7691 - loss: 0.2821 - val_lwlrap: 0.8672 - val_loss: 0.1606 - lr: 1.0000e-11
# Epoch 90/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8056 - loss: 0.2782 - val_lwlrap: 0.8631 - val_loss: 0.1610 - lr: 1.0000e-11
# Epoch 91/100
# 64/64 [==============================] - 19s 294ms/step - lwlrap: 0.8277 - loss: 0.2738 - val_lwlrap: 0.8607 - val_loss: 0.1625 - lr: 1.0000e-11
# Epoch 92/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.7978 - loss: 0.2851 - val_lwlrap: 0.8652 - val_loss: 0.1621 - lr: 1.0000e-12
# Epoch 93/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8218 - loss: 0.2797 - val_lwlrap: 0.8653 - val_loss: 0.1619 - lr: 1.0000e-12
# Epoch 94/100
# 64/64 [==============================] - 19s 293ms/step - lwlrap: 0.8030 - loss: 0.2874 - val_lwlrap: 0.8626 - val_loss: 0.1611 - lr: 1.0000e-12
# Epoch 95/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8002 - loss: 0.2818 - val_lwlrap: 0.8609 - val_loss: 0.1608 - lr: 1.0000e-12
# Epoch 96/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8091 - loss: 0.2859 - val_lwlrap: 0.8632 - val_loss: 0.1615 - lr: 1.0000e-12
# Epoch 97/100
# 64/64 [==============================] - 19s 293ms/step - lwlrap: 0.8121 - loss: 0.2821 - val_lwlrap: 0.8657 - val_loss: 0.1600 - lr: 1.0000e-12
# Epoch 98/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.8086 - loss: 0.2764 - val_lwlrap: 0.8655 - val_loss: 0.1603 - lr: 1.0000e-12
# Epoch 99/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8175 - loss: 0.2741 - val_lwlrap: 0.8642 - val_loss: 0.1606 - lr: 1.0000e-12
# Epoch 100/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.7933 - loss: 0.2773 - val_lwlrap: 0.8644 - val_loss: 0.1585 - lr: 1.0000e-12
# 16it [01:06,  4.13s/it]
# batchsize 128
# Epoch 1/100
# 64/64 [==============================] - 47s 736ms/step - lwlrap: 0.1519 - loss: 2.1466 - val_lwlrap: 0.1795 - val_loss: 0.7233 - lr: 0.0010
# Epoch 2/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.2015 - loss: 1.7048 - val_lwlrap: 0.2556 - val_loss: 0.6609 - lr: 0.0010
# Epoch 3/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.2209 - loss: 1.1566 - val_lwlrap: 0.2895 - val_loss: 0.4702 - lr: 0.0010
# Epoch 4/100
# 64/64 [==============================] - 19s 301ms/step - lwlrap: 0.2724 - loss: 0.7661 - val_lwlrap: 0.3738 - val_loss: 0.3740 - lr: 0.0010
# Epoch 5/100
# ...
# 64/64 [==============================] - 18s 275ms/step - lwlrap: 0.8252 - loss: 0.2612 - val_lwlrap: 0.8105 - val_loss: 10.5426 - lr: 1.0000e-12
# 16it [00:55,  3.49s/it]
# batchsize 128
# Epoch 1/100
# 64/64 [==============================] - 49s 769ms/step - lwlrap: 0.1695 - loss: 2.2075 - val_lwlrap: 0.1748 - val_loss: 0.6967 - lr: 0.0010
# Epoch 2/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.2078 - loss: 1.7208 - val_lwlrap: 0.2190 - val_loss: 0.7135 - lr: 0.0010
# Epoch 3/100
# 64/64 [==============================] - 19s 295ms/step - lwlrap: 0.2427 - loss: 1.2420 - val_lwlrap: 0.2614 - val_loss: 0.7140 - lr: 0.0010
# Epoch 4/100
# 64/64 [==============================] - 20s 309ms/step - lwlrap: 0.2835 - loss: 0.7983 - val_lwlrap: 0.3156 - val_loss: 0.5925 - lr: 0.0010
# Epoch 5/100
# 64/64 [==============================] - 20s 305ms/step - lwlrap: 0.3744 - loss: 0.5990 - val_lwlrap: 0.4723 - val_loss: 0.3451 - lr: 0.0010
# Epoch 6/100
# 64/64 [==============================] - 19s 296ms/step - lwlrap: 0.4940 - loss: 0.4897 - val_lwlrap: 0.5415 - val_loss: 0.3249 - lr: 0.0010
# Epoch 7/100
# 64/64 [==============================] - 17s 272ms/step - lwlrap: 0.5675 - loss: 0.4311 - val_lwlrap: 0.5127 - val_loss: 24.9898 - lr: 0.0010
# Epoch 8/100
# 64/64 [==============================] - 20s 307ms/step - lwlrap: 0.6753 - loss: 0.3677 - val_lwlrap: 0.7436 - val_loss: 2.5296 - lr: 0.0010
# Epoch 9/100
# 64/64 [==============================] - 20s 308ms/step - lwlrap: 0.7338 - loss: 0.3353 - val_lwlrap: 0.7702 - val_loss: 1.3752 - lr: 0.0010
# Epoch 10/100
# 64/64 [==============================] - 19s 302ms/step - lwlrap: 0.7457 - loss: 0.3112 - val_lwlrap: 0.8385 - val_loss: 0.1665 - lr: 0.0010
# Epoch 11/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.7888 - loss: 0.2931 - val_lwlrap: 0.7254 - val_loss: 30.9993 - lr: 0.0010
# Epoch 12/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.7872 - loss: 0.2786 - val_lwlrap: 0.7932 - val_loss: 12.7751 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - 17s 269ms/step - lwlrap: 0.8174 - loss: 0.2714 - val_lwlrap: 0.8103 - val_loss: 8.1412 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - 17s 270ms/step - lwlrap: 0.8067 - loss: 0.2685 - val_lwlrap: 0.8127 - val_loss: 7.4614 - lr: 1.0000e-04
# Epoch 15/100
# 64/64 [==============================] - 18s 275ms/step - lwlrap: 0.8296 - loss: 0.2715 - val_lwlrap: 0.8265 - val_loss: 7.1042 - lr: 1.0000e-04
# Epoch 16/100
# 64/64 [==============================] - 17s 269ms/step - lwlrap: 0.8060 - loss: 0.2749 - val_lwlrap: 0.8223 - val_loss: 7.1266 - lr: 1.0000e-04
# Epoch 17/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8062 - loss: 0.2729 - val_lwlrap: 0.8254 - val_loss: 7.2992 - lr: 1.0000e-04
# Epoch 18/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.8092 - loss: 0.2699 - val_lwlrap: 0.8195 - val_loss: 7.4380 - lr: 1.0000e-04
# Epoch 19/100
# 64/64 [==============================] - 17s 268ms/step - lwlrap: 0.8086 - loss: 0.2760 - val_lwlrap: 0.8230 - val_loss: 7.3854 - lr: 1.0000e-04
# Epoch 20/100
# 64/64 [==============================] - 17s 270ms/step - lwlrap: 0.8038 - loss: 0.2645 - val_lwlrap: 0.8239 - val_loss: 7.4385 - lr: 1.0000e-04
# Epoch 21/100
# 64/64 [==============================] - 17s 269ms/step - lwlrap: 0.8380 - loss: 0.2673 - val_lwlrap: 0.8343 - val_loss: 6.6248 - lr: 1.0000e-04
# Epoch 22/100
# 64/64 [==============================] - 18s 275ms/step - lwlrap: 0.8085 - loss: 0.2684 - val_lwlrap: 0.8271 - val_loss: 6.8947 - lr: 1.0000e-05
# Epoch 23/100
# 64/64 [==============================] - 17s 264ms/step - lwlrap: 0.8083 - loss: 0.2674 - val_lwlrap: 0.8190 - val_loss: 7.1189 - lr: 1.0000e-05
# Epoch 24/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8109 - loss: 0.2684 - val_lwlrap: 0.8202 - val_loss: 7.3465 - lr: 1.0000e-05
# Epoch 25/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8242 - loss: 0.2743 - val_lwlrap: 0.8285 - val_loss: 6.7439 - lr: 1.0000e-05
# Epoch 26/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8270 - loss: 0.2644 - val_lwlrap: 0.8223 - val_loss: 7.1241 - lr: 1.0000e-05
# Epoch 27/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8218 - loss: 0.2636 - val_lwlrap: 0.8196 - val_loss: 7.3186 - lr: 1.0000e-05
# Epoch 28/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.8217 - loss: 0.2649 - val_lwlrap: 0.8253 - val_loss: 7.5474 - lr: 1.0000e-05
# Epoch 29/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8106 - loss: 0.2702 - val_lwlrap: 0.8186 - val_loss: 7.5757 - lr: 1.0000e-05
# Epoch 30/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8138 - loss: 0.2674 - val_lwlrap: 0.8305 - val_loss: 6.7038 - lr: 1.0000e-05
# Epoch 31/100
# 64/64 [==============================] - 19s 293ms/step - lwlrap: 0.8202 - loss: 0.2691 - val_lwlrap: 0.8275 - val_loss: 6.7835 - lr: 1.0000e-05
# Epoch 32/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.8004 - loss: 0.2737 - val_lwlrap: 0.8294 - val_loss: 6.8444 - lr: 1.0000e-06
# Epoch 33/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8242 - loss: 0.2658 - val_lwlrap: 0.8291 - val_loss: 6.8067 - lr: 1.0000e-06
# Epoch 34/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8100 - loss: 0.2711 - val_lwlrap: 0.8250 - val_loss: 7.0456 - lr: 1.0000e-06
# Epoch 35/100
# 64/64 [==============================] - 17s 273ms/step - lwlrap: 0.8024 - loss: 0.2678 - val_lwlrap: 0.8308 - val_loss: 6.9763 - lr: 1.0000e-06
# Epoch 36/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8276 - loss: 0.2687 - val_lwlrap: 0.8306 - val_loss: 6.9955 - lr: 1.0000e-06
# Epoch 37/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8220 - loss: 0.2625 - val_lwlrap: 0.8348 - val_loss: 6.7489 - lr: 1.0000e-06
# Epoch 38/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8105 - loss: 0.2656 - val_lwlrap: 0.8265 - val_loss: 7.2516 - lr: 1.0000e-06
# Epoch 39/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8171 - loss: 0.2689 - val_lwlrap: 0.8220 - val_loss: 7.7551 - lr: 1.0000e-06
# Epoch 40/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.7969 - loss: 0.2674 - val_lwlrap: 0.8277 - val_loss: 7.6922 - lr: 1.0000e-06
# Epoch 41/100
# 64/64 [==============================] - 18s 274ms/step - lwlrap: 0.7998 - loss: 0.2685 - val_lwlrap: 0.8316 - val_loss: 7.4065 - lr: 1.0000e-06
# Epoch 42/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8259 - loss: 0.2681 - val_lwlrap: 0.8354 - val_loss: 7.0235 - lr: 1.0000e-07
# Epoch 43/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8195 - loss: 0.2659 - val_lwlrap: 0.8245 - val_loss: 8.0580 - lr: 1.0000e-07
# Epoch 44/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8222 - loss: 0.2658 - val_lwlrap: 0.8259 - val_loss: 7.9635 - lr: 1.0000e-07
# Epoch 45/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.8258 - loss: 0.2659 - val_lwlrap: 0.8153 - val_loss: 8.5978 - lr: 1.0000e-07
# Epoch 46/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8057 - loss: 0.2718 - val_lwlrap: 0.8185 - val_loss: 8.4621 - lr: 1.0000e-07
# Epoch 47/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8178 - loss: 0.2659 - val_lwlrap: 0.8193 - val_loss: 8.1839 - lr: 1.0000e-07
# Epoch 48/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8113 - loss: 0.2681 - val_lwlrap: 0.8211 - val_loss: 8.1690 - lr: 1.0000e-07
# Epoch 49/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8180 - loss: 0.2646 - val_lwlrap: 0.8231 - val_loss: 7.7550 - lr: 1.0000e-07
# Epoch 50/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8336 - loss: 0.2652 - val_lwlrap: 0.8219 - val_loss: 8.1499 - lr: 1.0000e-07
# Epoch 51/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8152 - loss: 0.2632 - val_lwlrap: 0.8275 - val_loss: 7.6668 - lr: 1.0000e-07
# Epoch 52/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8286 - loss: 0.2654 - val_lwlrap: 0.8313 - val_loss: 7.9534 - lr: 1.0000e-08
# Epoch 53/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8225 - loss: 0.2678 - val_lwlrap: 0.8282 - val_loss: 8.0377 - lr: 1.0000e-08
# Epoch 54/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8219 - loss: 0.2625 - val_lwlrap: 0.8261 - val_loss: 7.8272 - lr: 1.0000e-08
# Epoch 55/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8273 - loss: 0.2677 - val_lwlrap: 0.8303 - val_loss: 7.9669 - lr: 1.0000e-08
# Epoch 56/100
# 64/64 [==============================] - 18s 278ms/step - lwlrap: 0.8310 - loss: 0.2627 - val_lwlrap: 0.8279 - val_loss: 8.5523 - lr: 1.0000e-08
# Epoch 57/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8192 - loss: 0.2665 - val_lwlrap: 0.8199 - val_loss: 8.8137 - lr: 1.0000e-08
# Epoch 58/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8387 - loss: 0.2661 - val_lwlrap: 0.8323 - val_loss: 9.0642 - lr: 1.0000e-08
# Epoch 59/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8343 - loss: 0.2646 - val_lwlrap: 0.8324 - val_loss: 8.9562 - lr: 1.0000e-08
# Epoch 60/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8314 - loss: 0.2616 - val_lwlrap: 0.8305 - val_loss: 8.9288 - lr: 1.0000e-08
# Epoch 61/100
# 64/64 [==============================] - 19s 291ms/step - lwlrap: 0.8603 - loss: 0.2542 - val_lwlrap: 0.8350 - val_loss: 8.8882 - lr: 1.0000e-08
# Epoch 62/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8443 - loss: 0.2673 - val_lwlrap: 0.8180 - val_loss: 9.3283 - lr: 1.0000e-09
# Epoch 63/100
# 64/64 [==============================] - 18s 285ms/step - lwlrap: 0.8309 - loss: 0.2594 - val_lwlrap: 0.8250 - val_loss: 9.5342 - lr: 1.0000e-09
# Epoch 64/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8287 - loss: 0.2605 - val_lwlrap: 0.8265 - val_loss: 10.1123 - lr: 1.0000e-09
# Epoch 65/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8372 - loss: 0.2590 - val_lwlrap: 0.8242 - val_loss: 9.9426 - lr: 1.0000e-09
# Epoch 66/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8361 - loss: 0.2619 - val_lwlrap: 0.8210 - val_loss: 9.5957 - lr: 1.0000e-09
# Epoch 67/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.8063 - loss: 0.2644 - val_lwlrap: 0.8313 - val_loss: 9.4084 - lr: 1.0000e-09
# Epoch 68/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8374 - loss: 0.2621 - val_lwlrap: 0.8335 - val_loss: 8.8756 - lr: 1.0000e-09
# Epoch 69/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8455 - loss: 0.2607 - val_lwlrap: 0.8314 - val_loss: 9.0612 - lr: 1.0000e-09
# Epoch 70/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8248 - loss: 0.2594 - val_lwlrap: 0.8293 - val_loss: 9.5756 - lr: 1.0000e-09
# Epoch 71/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8424 - loss: 0.2565 - val_lwlrap: 0.8234 - val_loss: 9.7239 - lr: 1.0000e-09
# Epoch 72/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8443 - loss: 0.2588 - val_lwlrap: 0.8278 - val_loss: 9.7653 - lr: 1.0000e-10
# Epoch 73/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8496 - loss: 0.2560 - val_lwlrap: 0.8241 - val_loss: 10.6158 - lr: 1.0000e-10
# Epoch 74/100
# 64/64 [==============================] - 18s 279ms/step - lwlrap: 0.8288 - loss: 0.2555 - val_lwlrap: 0.8248 - val_loss: 11.0213 - lr: 1.0000e-10
# Epoch 75/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8241 - loss: 0.2550 - val_lwlrap: 0.8280 - val_loss: 11.3171 - lr: 1.0000e-10
# Epoch 76/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8497 - loss: 0.2571 - val_lwlrap: 0.8365 - val_loss: 10.7550 - lr: 1.0000e-10
# Epoch 77/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8384 - loss: 0.2564 - val_lwlrap: 0.8259 - val_loss: 11.3854 - lr: 1.0000e-10
# Epoch 78/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8332 - loss: 0.2613 - val_lwlrap: 0.8282 - val_loss: 11.1615 - lr: 1.0000e-10
# Epoch 79/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8150 - loss: 0.2573 - val_lwlrap: 0.8279 - val_loss: 10.7255 - lr: 1.0000e-10
# Epoch 80/100
# 64/64 [==============================] - 19s 290ms/step - lwlrap: 0.8411 - loss: 0.2629 - val_lwlrap: 0.8340 - val_loss: 10.7602 - lr: 1.0000e-10
# Epoch 81/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8432 - loss: 0.2533 - val_lwlrap: 0.8316 - val_loss: 11.1823 - lr: 1.0000e-10
# Epoch 82/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8115 - loss: 0.2583 - val_lwlrap: 0.8292 - val_loss: 11.2896 - lr: 1.0000e-11
# Epoch 83/100
# 64/64 [==============================] - 18s 287ms/step - lwlrap: 0.8130 - loss: 0.2502 - val_lwlrap: 0.8314 - val_loss: 11.3603 - lr: 1.0000e-11
# Epoch 84/100
# 64/64 [==============================] - 18s 278ms/step - lwlrap: 0.8342 - loss: 0.2549 - val_lwlrap: 0.8268 - val_loss: 11.1498 - lr: 1.0000e-11
# Epoch 85/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8425 - loss: 0.2510 - val_lwlrap: 0.8222 - val_loss: 11.6058 - lr: 1.0000e-11
# Epoch 86/100
# 64/64 [==============================] - 18s 284ms/step - lwlrap: 0.8533 - loss: 0.2514 - val_lwlrap: 0.8317 - val_loss: 11.2440 - lr: 1.0000e-11
# Epoch 87/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8459 - loss: 0.2520 - val_lwlrap: 0.8375 - val_loss: 10.0665 - lr: 1.0000e-11
# Epoch 88/100
# 64/64 [==============================] - 19s 289ms/step - lwlrap: 0.8479 - loss: 0.2473 - val_lwlrap: 0.8340 - val_loss: 10.7536 - lr: 1.0000e-11
# Epoch 89/100
# 64/64 [==============================] - 18s 282ms/step - lwlrap: 0.8446 - loss: 0.2524 - val_lwlrap: 0.8334 - val_loss: 11.0478 - lr: 1.0000e-11
# Epoch 90/100
# 64/64 [==============================] - 18s 283ms/step - lwlrap: 0.8412 - loss: 0.2480 - val_lwlrap: 0.8174 - val_loss: 13.3406 - lr: 1.0000e-11
# Epoch 91/100
# 64/64 [==============================] - 18s 289ms/step - lwlrap: 0.8547 - loss: 0.2507 - val_lwlrap: 0.8334 - val_loss: 13.1008 - lr: 1.0000e-11
# Epoch 92/100
# 64/64 [==============================] - 20s 319ms/step - lwlrap: 0.8498 - loss: 0.2508 - val_lwlrap: 0.8390 - val_loss: 13.0079 - lr: 1.0000e-12
# Epoch 93/100
# 64/64 [==============================] - 17s 270ms/step - lwlrap: 0.8560 - loss: 0.2456 - val_lwlrap: 0.8289 - val_loss: 12.8473 - lr: 1.0000e-12
# Epoch 94/100
# 64/64 [==============================] - 18s 277ms/step - lwlrap: 0.8402 - loss: 0.2494 - val_lwlrap: 0.8308 - val_loss: 11.4893 - lr: 1.0000e-12
# Epoch 95/100
# 64/64 [==============================] - 18s 276ms/step - lwlrap: 0.8397 - loss: 0.2480 - val_lwlrap: 0.8281 - val_loss: 11.1983 - lr: 1.0000e-12
# Epoch 96/100
# 64/64 [==============================] - 17s 266ms/step - lwlrap: 0.8437 - loss: 0.2519 - val_lwlrap: 0.8279 - val_loss: 11.1687 - lr: 1.0000e-12
# Epoch 97/100
# 64/64 [==============================] - 18s 286ms/step - lwlrap: 0.8462 - loss: 0.2522 - val_lwlrap: 0.8283 - val_loss: 11.2394 - lr: 1.0000e-12
# Epoch 98/100
# 64/64 [==============================] - 18s 288ms/step - lwlrap: 0.8232 - loss: 0.2500 - val_lwlrap: 0.8360 - val_loss: 11.0367 - lr: 1.0000e-12
# Epoch 99/100
# 64/64 [==============================] - 18s 280ms/step - lwlrap: 0.8392 - loss: 0.2481 - val_lwlrap: 0.8278 - val_loss: 10.9674 - lr: 1.0000e-12
# Epoch 100/100
# 64/64 [==============================] - 18s 281ms/step - lwlrap: 0.8360 - loss: 0.2441 - val_lwlrap: 0.8235 - val_loss: 11.0235 - lr: 1.0000e-12
# 16it [00:56,  3.52s/it]

# %%
sub.describe()
# Out:
#                 s0           s1           s2           s3           s4  \
# count  1992.000000  1992.000000  1992.000000  1992.000000  1992.000000
# mean      0.840249     0.842116     0.737863     1.379043     0.627942
# std       0.690282     0.525384     0.621337     0.462301     0.306086
# min       0.308705     0.259589     0.339726     0.371036     0.243068
# 25%       0.551710     0.560078     0.509700     1.030829     0.516726
# 50%       0.626578     0.671687     0.590407     1.345562     0.570003
# 75%       0.777997     0.873971     0.703994     1.690380     0.645452
# max       4.564555     4.048100     4.937202     2.984776     4.562220
#
#                 s5           s6           s7           s8           s9  ...  \
# count  1992.000000  1992.000000  1992.000000  1992.000000  1992.000000  ...
# mean      1.025097     0.666163     1.169208     0.701042     0.786427  ...
# std       0.587310     0.334262     0.647878     0.450391     0.307636  ...
# min       0.291434     0.274764     0.357019     0.322294     0.359136  ...
# 25%       0.645498     0.507295     0.731711     0.519237     0.629744  ...
# 50%       0.862217     0.591703     0.961413     0.584662     0.722780  ...
# 75%       1.223590     0.727921     1.346576     0.687134     0.864846  ...
# max       4.592889     4.926350     3.655338     4.560266     4.452615  ...
#
#                s14          s15          s16          s17          s18  \
# count  1992.000000  1992.000000  1992.000000  1992.000000  1992.000000
# mean      0.846765     1.084859     0.924620     0.724156     0.827581
# std       0.679511     1.065607     0.767801     0.528920     0.433416
# min       0.216356     0.310058     0.260941     0.260143     0.299051
# 25%       0.561692     0.556551     0.560307     0.497779     0.558445
# 50%       0.663668     0.658434     0.672875     0.594411     0.659734
# 75%       0.806803     0.893090     0.881453     0.747030     0.944392
# max       4.708787     4.905145     4.834661     4.876954     3.537036
#
#                s19          s20          s21          s22          s23
# count  1992.000000  1992.000000  1992.000000  1992.000000  1992.000000
# mean      0.664913     0.832459     0.657778     0.743452     1.083077
# std       0.317333     0.418482     0.186959     0.443865     0.816201
# min       0.291213     0.384312     0.323677     0.340083     0.150226
# 25%       0.527772     0.585887     0.562428     0.574032     0.617089
# 50%       0.591412     0.719446     0.624024     0.665517     0.842765
# 75%       0.683878     0.936281     0.702673     0.786765     1.195167
# max       4.814721     4.979994     2.674620     4.985796     4.967672
#
# [8 rows x 24 columns]

# %%
sub.to_csv("submission.csv", index=False)
